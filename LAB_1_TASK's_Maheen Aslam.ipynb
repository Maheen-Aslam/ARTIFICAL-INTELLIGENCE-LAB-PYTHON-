# %% [markdown]
# **Print statement**

# %%
print("maheen")
# Out:
# maheen

# %% [markdown]
# **print command**

# %%
# my name
print("maheen Aslam")
# Out:
# maheen Aslam

# %% [markdown]
# **MUlti line comment**

# %%
""" multi line """
# Out:
# ' multi line '

# %%
x=6
y="ahmad"
print(x)
print(y)
# Out:
# 6
# ahmad

# %% [markdown]
# **Check string without quotation**

# %%
z=ahmad
print(z)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-38a46de25f61> in <cell line: 1>()
# ----> 1 z=ahmad
#       2 print(z)
#
# NameError: name 'ahmad' is not defined

# %%
y=str(10)
print(y,type(y))
# Out:
# 10 <class 'str'>

# %% [markdown]
#  **Check string make int type casting**

# %%
#check type
x=int("a")
print(type(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-fb86b9dd5656> in <cell line: 2>()
#       1 #check type
# ----> 2 x=int("a")
#       3 print(type(x))
#
# ValueError: invalid literal for int() with base 10: 'a'

# %% [markdown]
# **Type casting**

# %%
x=str(3)
y=int(3)
z=float(3)
print(x,type(x))
print(y,type(y))
print(z,type(z))
# Out:
# 3 <class 'str'>
# 3 <class 'int'>
# 3.0 <class 'float'>

# %% [markdown]
# **Variable name**
# variable declaration not started with numbers or special characters

# %%
myvar="Ahmad"
myVar="Ahmad"
my_var="ahmad rehmat"
print(myvar)
print(myVar)
print(my_var)
# Out:
# Ahmad
# Ahmad
# ahmad rehmat

# %% [markdown]
# **Many values of multiple variable**

# %%
x,y,z="maheen","ahmad","mahnoor"
print(x)
print(y)
print(z)
# Out:
# maheen
# ahmad
# mahnoor

# %% [markdown]
# **variable can change data**

# %%
x = 4       # x is of type int
x = "Sally" # x is now of type str
print(x)
# Out:
# Sally

# %% [markdown]
# **print multiple variable value**

# %%
x,y,z="maheen","ahmad","mahnoor"
print(x,y,z)
# Out:
# maheen ahmad mahnoor

# %% [markdown]
# **string or int not concatenate through + sign**

# %%
a=5
b="maheen"
print(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-bf7dc6b270ac> in <cell line: 3>()
#       1 a=5
#       2 b="maheen"
# ----> 3 print(a+b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **local variable**

# %%
x="maheen"
def fun1():
  x="ahmad"
  print("MY name is " ,x)
fun1()
print("my name is ",x)
# Out:
# MY name is  ahmad
# my name is  maheen

# %% [markdown]
# **Global Variables**

# %%
def myfunc():
 global x
 x = "fantastic"
myfunc()
print("Python is " + x)
# Out:
# Python is fantastic
